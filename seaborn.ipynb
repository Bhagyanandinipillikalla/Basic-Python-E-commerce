# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('tips')

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.set(style='whitegrid',context='talk')
sns.histplot(data=df,x='total_bill',hue='sex',palette='colorblind')
plt.show()

# %%
sns.set(style='white',context='talk')
sns.histplot(data=df,x='total_bill',hue='smoker',palette='colorblind')
plt.show()

# %%
sns.set(style='white',context='talk')
sns.histplot(data=df,x='total_bill',hue='day',palette='colorblind')
plt.show()

# %%
sns.set(style='white',context='talk')
sns.histplot(data=df,x='total_bill',hue='time',palette='colorblind')
plt.show()

# %%
sns.set(style='white',context='talk')
sns.histplot(data=df,x='tip',hue='sex',palette='colorblind')
plt.show()

# %%
sns.set(style='white',context='talk')
sns.histplot(data=df,x='tip',hue='smoker',palette='colorblind')
plt.show()

# %%
sns.set(style='white',context='talk')
sns.histplot(data=df,x='tip',hue='day',palette='colorblind')
plt.show()

# %%
sns.set(style='white',context='talk')
sns.histplot(data=df,x='tip',hue='time',palette='colorblind')
plt.show()

# %%
sns.jointplot(data=df,x='total_bill',y='tip',hue='sex',color='red')
plt.show()

# %%
sns.jointplot(data=df,x='total_bill',y='tip',hue='sex',kind='kde',color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.jointplot(data=df,x='total_bill',y='tip',hue='sex',kind='kde',color='red')
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.pairplot(data=df,hue='sex')
plt.show()
